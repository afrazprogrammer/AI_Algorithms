# %%
print("Hello World")
# Out:
# Hello World

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

df = pd.read_csv("USA_Housing dataset-lab 02.csv")
ss = StandardScaler()

df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df = df.drop('Address', axis = 1)
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
aai = np.array([df['Avg. Area Income']])
ap = np.array([df['Area Population']])

aai = aai.T
ap = ap.T

print(aai.shape)
print(ap.shape)

ss.fit(aai)
df['Avg. Area Income'] = ss.transform(aai)
ss.fit(ap)
df['Area Population'] = ss.transform(ap)

df.describe()
# Out:
# (5000, 1)
# (5000, 1)
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count      5.000000e+03          5000.000000                5000.000000
# mean       6.039613e-18             5.977222                   6.987792
# std        1.000100e+00             0.991456                   1.005833
# min       -4.765584e+00             2.644304                   3.236194
# 25%       -6.664724e-01             5.322283                   6.299250
# 50%        2.075434e-02             5.970429                   7.002902
# 75%        6.756386e-01             6.650808                   7.665871
# max        3.670725e+00             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000     5.000000e+03  5.000000e+03
# mean                       3.981330     4.035883e-16  1.232073e+06
# std                        1.234137     1.000100e+00  3.531176e+05
# ...

# %%
df.corr()['Price']
# Out:
# Avg. Area Income                0.639734
# Avg. Area House Age             0.452543
# Avg. Area Number of Rooms       0.335664
# Avg. Area Number of Bedrooms    0.171071
# Area Population                 0.408556
# Price                           1.000000
# Name: Price, dtype: float64

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\SE Lab\AppData\Local\Temp\ipykernel_9908\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(df['Avg. Area Income'])
# Out:
# C:\Users\SE Lab\AppData\Local\Temp\ipykernel_9908\1518947423.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Avg. Area Income'])
# <Axes: xlabel='Avg. Area Income', ylabel='Density'>

# %%
sns.distplot(df['Avg. Area House Age'])
# Out:
# C:\Users\SE Lab\AppData\Local\Temp\ipykernel_9908\2574366960.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Avg. Area House Age'])
# <Axes: xlabel='Avg. Area House Age', ylabel='Density'>

# %%
sns.distplot(df['Area Population'])
# Out:
# C:\Users\SE Lab\AppData\Local\Temp\ipykernel_9908\2894963991.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Area Population'])
# <Axes: xlabel='Area Population', ylabel='Density'>

# %% [markdown]
# According to the data above the important features are:

# %% [markdown]
# 1. Avg. Area Income
# 2. Avg. Area House Age
# 3. Area Population
# 4. Avg. Number of Rooms
#
# In increasing order

# %%
X = np.array([df['Avg. Area Income'], df['Avg. Area House Age'], df['Area Population'], df['Avg. Area Number of Rooms']])
X = X.T
X.shape
# Out:
# (5000, 4)

# %%
y = df['Price']

y.shape
# Out:
# (5000,)

# %%
from sklearn.model_selection import train_test_split

X_train, x_test, Y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

print(X_train.shape)
print(Y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (4000, 4)
# (4000,)
# (1000, 4)
# (1000,)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, Y_train)

predictions = model.predict(x_test)

plt.figure(figsize = (20, 20))
plt.plot(sorted(x_test.T[0]), y_test, color = 'blue')
plt.plot(sorted(x_test.T[0]), predictions, color = 'red')
plt.show()

# %% [markdown]
# Finding MSE

# %%
from sklearn.metrics import root_mean_squared_error

root_mean_squared_error(y_test, predictions)
# Out:
# 102518.09668582464

# %%
import sklearn

sklearn.__version__
# Out:
# '1.4.0'

# %%
# !pip install --upgrade scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
